# %% [markdown]
# # Kaggle Qwen2.5 3B GRPO Run
#
# Use this notebook from the Kaggle-backed VS Code kernel. It runs the complementary 3B Unsloth GRPO experiment while the campus server runs the default 1.5B job.

# %% [markdown]
# ## 1. GPU Check
#
# Expected on Kaggle: two T4 GPUs. If this cell does not show T4s, the notebook is not attached to the Kaggle kernel.

# %%
# !nvidia-smi
# Out:
# Sat Apr 25 00:45:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   37C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Bootstrap Kaggle Working Directory And Repo
#
# The Kaggle kernel cannot see your local laptop path. This section resets the remote kernel to `/kaggle/working`, then clones or updates the pushed `round2-redshift` branch. Run these cells even if a previous `%cd` failed.

# %%
import os
from pathlib import Path

Path("/kaggle/working").mkdir(parents=True, exist_ok=True)
os.chdir("/kaggle/working")
print("cwd:", os.getcwd())
# Out:
# cwd: /kaggle/working

# %%
import os, shutil, subprocess, time
from pathlib import Path

REPO_URL = "https://github.com/srimanreddy4/MetaHackathon-R2"
BRANCH = "round2-redshift"
WORKDIR = Path("/kaggle/working/MetaHackathon-R2")

os.chdir("/kaggle/working")
if (WORKDIR / ".git").exists():
    os.chdir(WORKDIR)
    subprocess.run(["git", "fetch", "origin", BRANCH], check=True)
    subprocess.run(["git", "checkout", BRANCH], check=True)
    subprocess.run(["git", "pull", "--ff-only", "origin", BRANCH], check=True)
else:
    if WORKDIR.exists():
        backup = WORKDIR.with_name(f"{WORKDIR.name}.bak.{int(time.time())}")
        shutil.move(str(WORKDIR), str(backup))
        print("Moved non-git existing directory to", backup)
    subprocess.run(["git", "clone", "-b", BRANCH, REPO_URL, str(WORKDIR)], check=True)
    os.chdir(WORKDIR)

print("cwd:", os.getcwd())
subprocess.run(["git", "log", "--oneline", "-5"], check=True)
# Out:
# From https://github.com/srimanreddy4/MetaHackathon-R2
#  * branch            round2-redshift -> FETCH_HEAD
#    091fc35..5ec7173  round2-redshift -> origin/round2-redshift
# Already on 'round2-redshift'
# Your branch is behind 'origin/round2-redshift' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# Updating 091fc35..5ec7173
# Fast-forward
#  scripts/run_kaggle_qwen3b_grpo.sh |  6 +++--
#  scripts/train_unsloth_grpo.py     | 55 ++++++++++++++++++++++++++++++++++++---
#  2 files changed, 56 insertions(+), 5 deletions(-)
# cwd: /kaggle/working/MetaHackathon-R2
# 5ec7173 fix: keep unsloth grpo lora trainable
# 091fc35 fix: make kaggle notebook bootstrap repo safely
# bee18a1 fix: make kaggle grpo runner import package
# 38e9283 training: add kaggle qwen3b grpo runner
# 3f54d9d docs: add unsloth grpo runbook
# From https://github.com/srimanreddy4/MetaHackathon-R2
#  * branch            round2-redshift -> FETCH_HEAD
# CompletedProcess(args=['git', 'log', '--oneline', '-5'], returncode=0)

# %%
# %cd /kaggle/working/MetaHackathon-R2
# %env PYTHONPATH=src:scripts
# !python - <<'PY'
import os
from pathlib import Path
print("cwd=", Path.cwd())
print("PYTHONPATH=", os.environ.get("PYTHONPATH"))
print("repo exists=", Path("src/oncallenv").exists())
# Out:
# /kaggle/working/MetaHackathon-R2
# env: PYTHONPATH=src:scripts
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# cwd= /kaggle/working/MetaHackathon-R2
# PYTHONPATH= src:scripts
# repo exists= True

# %% [markdown]
# ## 3. Install Dependencies
#
# Run the normal install first. If Kaggle has a PyTorch/CUDA dependency conflict, use the fallback cell after it.

# %%
# !python -m pip install -U pip setuptools wheel
# !python -m pip install -r requirements.txt
# !python -m pip install -r requirements-llm.txt
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (82.0.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Requirement already satisfied: openenv-core>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: fastapi>=0.104.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.133.0)
# Requirement already satisfied: uvicorn>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.41.0)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.12.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: openai>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.23.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: rich>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: huggingface_hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: tomli>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: tomli-w>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: websockets>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (15.0.1)
# Requirement already satisfied: fastmcp>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.2.4)
# Requirement already satisfied: gradio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (5.50.0)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.104.0->-r requirements.txt (line 2)) (0.52.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.104.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.104.0->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.104.0->-r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.24.0->-r requirements.txt (line 3)) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.24.0->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->-r requirements.txt (line 4)) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (2026.1.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.6.0->-r requirements.txt (line 7)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.6.0->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.6.0->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.6.0->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.6.0->-r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: authlib>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.6.8)
# Requirement already satisfied: cyclopts>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: griffelib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.4.5)
# Requirement already satisfied: mcp<2.0,>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.26.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: opentelemetry-api>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: platformdirs>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (4.9.2)
# Requirement already satisfied: py-key-value-aio<0.5.0,>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: uncalled-for>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: watchfiles>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: beartype>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio<0.5.0,>=0.4.4->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.22.9)
# Requirement already satisfied: aiofile>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: keyring>=25.6.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (6.2.6)
# Requirement already satisfied: caio<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from aiofile>=3.5.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib>=1.6.5->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (43.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.21.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.11.7)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.25.1)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.15.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2026.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.20.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.24.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.20.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: pathable<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path>=0.3.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.20.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.20.0->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.7->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib>=1.6.5->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib>=1.6.5->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=4.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp>=3.0.0->openenv-core>=0.2.0->-r requirements.txt (line 1)) (10.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: transformers>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 2)) (4.57.2)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 3)) (4.8.3)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 4)) (1.12.0)
# Requirement already satisfied: trl>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 5)) (0.23.0)
# Requirement already satisfied: peft>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 6)) (0.18.1)
# Requirement already satisfied: bitsandbytes>=0.45.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 7)) (0.49.2)
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 8)) (2025.11.1)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-llm.txt (line 9)) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements-llm.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements-llm.txt (line 1)) (1.3.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->-r requirements-llm.txt (line 2)) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.51.0->-r requirements-llm.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->-r requirements-llm.txt (line 3)) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (0.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->-r requirements-llm.txt (line 4)) (5.9.5)
# Requirement already satisfied: unsloth_zoo>=2025.11.1 in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (2025.11.2)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.47.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.25.0+cu128)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (1.0.13)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (5.29.5)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.0.35)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.2.1)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth->-r requirements-llm.txt (line 8)) (0.36.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->-r requirements-llm.txt (line 9)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.51.0->-r requirements-llm.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.51.0->-r requirements-llm.txt (line 2)) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements-llm.txt (line 1)) (1.3.0)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.11.1->unsloth->-r requirements-llm.txt (line 8)) (0.17.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.11.1->unsloth->-r requirements-llm.txt (line 8)) (25.1.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.11.1->unsloth->-r requirements-llm.txt (line 8)) (0.21.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth->-r requirements-llm.txt (line 8)) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth->-r requirements-llm.txt (line 8)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements-llm.txt (line 1)) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->-r requirements-llm.txt (line 3)) (2025.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth->-r requirements-llm.txt (line 8)) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth->-r requirements-llm.txt (line 8)) (4.5.1)

# %%
# Fallback install if the previous cell fails:
# !python -m pip install -U transformers datasets accelerate trl peft bitsandbytes unsloth

# %% [markdown]
# ## 4. Verify Environment
#
# Expected: `21 passed` and OpenEnv validation OK.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh verify
# Out:
# .....................                                                    [100%]
# 21 passed in 4.91s
# [OK] : Ready for multi-mode deployment

# %% [markdown]
# ## 5. Small 3B Smoke Run
#
# This is intentionally small. Continue only if it writes `training_results/unsloth_grpo_qwen3b_smoke/summary.json`.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh smoke
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-04-25 00:45:53.953071: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777077953.976606     980 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777077953.984531     980 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777077954.004050     980 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777077954.004082     980 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777077954.004086     980 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777077954.004090     980 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# ==((====))==  Unsloth 2025.11.1: Fast Qwen2 patching. Transformers: 4.57.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.11.1 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.
# trainable params: 29,933,568 || all params: 3,115,872,256 || trainable%: 0.9607
# Trainable parameter report: {'total': 1728606208, 'trainable': 29933568, 'lora_tensors': 504}
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 40 | Num Epochs = 5 | Total steps = 50
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 29,933,568 of 3,115,872,256 (0.96% trained)
#   0%|                                                    | 0/50 [00:00<?, ?it/s]Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': 0.0, 'grad_norm': 0.7815998196601868, 'learning_rate': 3e-06, 'num_tokens': 15350.0, 'completions/mean_length': 125.1, 'completions/min_length': 109.2, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.925, 'completions/mean_terminated_length': 35.4, 'completions/min_terminated_length': 32.4, 'completions/max_terminated_length': 38.4, 'rewards/redshift_reward/mean': 0.3012454152107239, 'rewards/redshift_reward/std': 0.05380152203142643, 'reward': 0.30124542117118835, 'reward_std': 0.05380151979625225, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 2.7220614720135926e-05, 'epoch': 0.5}
# {'loss': 0.0, 'grad_norm': 0.5200132131576538, 'learning_rate': 4.666666666666667e-06, 'num_tokens': 30606.0, 'completions/mean_length': 121.6, 'completions/min_length': 96.0, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.9, 'completions/mean_terminated_length': 25.6, 'completions/min_terminated_length': 19.2, 'completions/max_terminated_length': 32.0, 'rewards/redshift_reward/mean': 0.3120946824550629, 'rewards/redshift_reward/std': 0.10945373997092248, 'reward': 0.3120946764945984, 'reward_std': 0.10945373475551605, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.0001561123877763748, 'epoch': 1.0}
# {'loss': 0.0001, 'grad_norm': 0.235799178481102, 'learning_rate': 4.111111111111111e-06, 'num_tokens': 45688.0, 'completions/mean_length': 118.05, 'completions/min_length': 78.4, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.85, 'completions/mean_terminated_length': 37.6, 'completions/min_terminated_length': 27.2, 'completions/max_terminated_length': 47.6, 'rewards/redshift_reward/mean': 0.30027249455451965, 'rewards/redshift_reward/std': 0.07548941150307656, 'reward': 0.30027249455451965, 'reward_std': 0.07548940591514111, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.004315137420780957, 'epoch': 1.5}
# {'loss': 0.0001, 'grad_norm': inf, 'learning_rate': 3.555555555555556e-06, 'num_tokens': 61079.0, 'completions/mean_length': 125.325, 'completions/min_length': 107.4, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.925, 'completions/mean_terminated_length': 37.6, 'completions/min_terminated_length': 30.6, 'completions/max_terminated_length': 44.6, 'rewards/redshift_reward/mean': 0.3181111395359039, 'rewards/redshift_reward/std': 0.06877542063593864, 'reward': 0.31811113357543946, 'reward_std': 0.06877542249858379, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.003969983919523657, 'epoch': 2.0}
# {'loss': 0.0001, 'grad_norm': 0.6300954818725586, 'learning_rate': 3.1111111111111116e-06, 'num_tokens': 76193.0, 'completions/mean_length': 119.45, 'completions/min_length': 91.6, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.9, 'completions/mean_terminated_length': 17.0, 'completions/min_terminated_length': 14.8, 'completions/max_terminated_length': 19.2, 'rewards/redshift_reward/mean': 0.3077217698097229, 'rewards/redshift_reward/std': 0.06324909180402756, 'reward': 0.3077217698097229, 'reward_std': 0.06324908807873726, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.006189085508231074, 'epoch': 2.5}
# {'loss': 0.0001, 'grad_norm': 2.559072494506836, 'learning_rate': 2.5555555555555557e-06, 'num_tokens': 91353.0, 'completions/mean_length': 118.95, 'completions/min_length': 82.6, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.8, 'completions/mean_terminated_length': 71.5, 'completions/min_terminated_length': 57.0, 'completions/max_terminated_length': 89.8, 'rewards/redshift_reward/mean': 0.3074594736099243, 'rewards/redshift_reward/std': 0.07491497360169888, 'reward': 0.3074594736099243, 'reward_std': 0.07491497099399566, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.004764620773494243, 'epoch': 3.0}
# {'loss': 0.0, 'grad_norm': 0.6140585541725159, 'learning_rate': 2.0000000000000003e-06, 'num_tokens': 106800.0, 'completions/mean_length': 127.275, 'completions/min_length': 122.2, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.975, 'completions/mean_terminated_length': 19.8, 'completions/min_terminated_length': 19.8, 'completions/max_terminated_length': 19.8, 'rewards/redshift_reward/mean': 0.3077631235122681, 'rewards/redshift_reward/std': 0.06138145327568054, 'reward': 0.30776312947273254, 'reward_std': 0.061381452903151515, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.0022307227714918553, 'epoch': 3.5}
# {'loss': 0.0001, 'grad_norm': 0.7890934944152832, 'learning_rate': 1.4444444444444445e-06, 'num_tokens': 122123.0, 'completions/mean_length': 123.525, 'completions/min_length': 103.2, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.925, 'completions/mean_terminated_length': 27.1, 'completions/min_terminated_length': 26.4, 'completions/max_terminated_length': 27.8, 'rewards/redshift_reward/mean': 0.3096939504146576, 'rewards/redshift_reward/std': 0.063520747423172, 'reward': 0.3096939563751221, 'reward_std': 0.06352074667811394, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.006417171796783805, 'epoch': 4.0}
# {'loss': 0.0001, 'grad_norm': 0.40829238295555115, 'learning_rate': 8.88888888888889e-07, 'num_tokens': 137568.0, 'completions/mean_length': 126.975, 'completions/min_length': 119.8, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.975, 'completions/mean_terminated_length': 17.4, 'completions/min_terminated_length': 17.4, 'completions/max_terminated_length': 17.4, 'rewards/redshift_reward/mean': 0.29086561799049376, 'rewards/redshift_reward/std': 0.05380883514881134, 'reward': 0.2908656060695648, 'reward_std': 0.0538088358938694, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.0032004911452531816, 'epoch': 4.5}
# {'loss': 0.0002, 'grad_norm': 1.1079264879226685, 'learning_rate': 3.3333333333333335e-07, 'num_tokens': 152879.0, 'completions/mean_length': 123.475, 'completions/min_length': 98.0, 'completions/max_length': 128.0, 'completions/clipped_ratio': 0.925, 'completions/mean_terminated_length': 24.9, 'completions/min_terminated_length': 21.2, 'completions/max_terminated_length': 28.6, 'rewards/redshift_reward/mean': 0.33392344117164613, 'rewards/redshift_reward/std': 0.09634854681789876, 'reward': 0.3339234471321106, 'reward_std': 0.09634854383766651, 'frac_reward_zero_std': 0.0, 'completion_length': 128.0, 'kl': 0.007738945132587105, 'epoch': 5.0}
# 100%|███████████████████████████████████████████| 50/50 [22:24<00:00, 25.75s/it]Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# {'train_runtime': 1345.6838, 'train_samples_per_second': 0.297, 'train_steps_per_second': 0.037, 'train_loss': 7.80138373374939e-05, 'epoch': 5.0}
# 100%|███████████████████████████████████████████| 50/50 [22:25<00:00, 26.91s/it]
# {
#   "model_name": "unsloth/Qwen2.5-3B-Instruct-bnb-4bit",
#   "duration_sec": 1472.0738599300385,
#   "max_steps": 50,
#   "num_train_tasks": 40,
#   "num_eval_tasks": 8,
#   "curriculum_buffer": "curriculum_results/buffer.json",
#   "baseline_mean_reward": 0.261484375,
#   "trained_mean_reward": 0.31451562499999997,
#   "adapter_dir": "training_results/unsloth_grpo_qwen3b_smoke/adapter",
#   "dataset_path": "training_results/unsloth_grpo_qwen3b_smoke/dataset.jsonl",
#   "trainable_parameter_report": {
#     "total": 1728606208,
#     "trainable": 29933568,
#     "lora_tensors": 504
#   }
# }

# %%
# !cat training_results/unsloth_grpo_qwen3b_smoke/summary.json
# Out:
# {
#   "model_name": "unsloth/Qwen2.5-3B-Instruct-bnb-4bit",
#   "duration_sec": 1472.0738599300385,
#   "max_steps": 50,
#   "num_train_tasks": 40,
#   "num_eval_tasks": 8,
#   "curriculum_buffer": "curriculum_results/buffer.json",
#   "baseline_mean_reward": 0.261484375,
#   "trained_mean_reward": 0.31451562499999997,
#   "adapter_dir": "training_results/unsloth_grpo_qwen3b_smoke/adapter",
#   "dataset_path": "training_results/unsloth_grpo_qwen3b_smoke/dataset.jsonl",
#   "trainable_parameter_report": {
#     "total": 1728606208,
#     "trainable": 29933568,
#     "lora_tensors": 504
#   }
# }

# %% [markdown]
# ## 6. Main Kaggle 3B Run
#
# This is the main complementary run: Qwen2.5 3B, 160 curriculum tasks, 600 GRPO steps.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh main
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-04-25 01:17:23.241243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777079843.264508    1261 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777079843.272565    1261 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777079843.293539    1261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777079843.293584    1261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777079843.293588    1261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777079843.293592    1261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# ==((====))==  Unsloth 2025.11.1: Fast Qwen2 patching. Transformers: 4.57.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.11.1 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.
# trainable params: 29,933,568 || all params: 3,115,872,256 || trainable%: 0.9607
# Trainable parameter report: {'total': 1728606208, 'trainable': 29933568, 'lora_tensors': 504}
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 160 | Num Epochs = 30 | Total steps = 600
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 8 x 1) = 16
#  "-____-"     Trainable parameters = 29,933,568 of 3,115,872,256 (0.96% trained)
#   0%|                                                   | 0/600 [00:00<?, ?it/s]Unsloth: Will smartly offload gradients to save VRAM!
#   0%|                                        | 1/600 [01:07<11:16:03, 67.72s/it]^C
# Traceback (most recent call last):
#   File "/kaggle/working/MetaHackathon-R2/scripts/train_unsloth_grpo.py", line 415, in <module>
#     main()
#   File "/kaggle/working/MetaHackathon-R2/scripts/train_unsloth_grpo.py", line 390, in main
#     trainer.train()
#   File "/kaggle/working/MetaHackathon-R2/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 53, in wrapper
#     output = f(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 2325, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 330, in _fast_inner_training_loop
#   File "<string>", line 34, in _unsloth_training_step
#   File "/usr/local/lib/python3.12/dist-packages/trl/extras/profiling.py", line 98, in wrapper
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/MetaHackathon-R2/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 2177, in _prepare_inputs
#     generation_batch = self._generate_and_score_completions(generation_batch)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/MetaHackathon-R2/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 2507, in _generate_and_score_completions
#     prompt_completion_ids = unwrapped_model.generate(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/rl.py", line 71, in generate_with_clone
#     out = original_generate(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/peft/peft_model.py", line 2048, in generate
#     outputs = self.base_model.generate(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py", line 1774, in unsloth_fast_generate
#     output = self._old_generate(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py", line 2564, in generate
#     result = decoding_method(
#              ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py", line 2787, in _sample
#     outputs = model_forward(**model_inputs, return_dict=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py", line 1140, in _CausalLM_fast_forward
#     outputs = fast_forward_inference(
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py", line 1073, in LlamaModel_fast_forward_inference_custom
#     X, present_key_value = attention_fast_forward_inference(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py", line 281, in LlamaAttention_fast_forward_inference
#     Qn = fast_linear_forward(self.q_proj, Xn, out = self.temp_QA[0])
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/kernels/utils.py", line 736, in fast_linear_forward
#     out = torch_matmul(X, W, out = out)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !cat training_results/unsloth_grpo_qwen3b_kaggle/summary.json
# !bash scripts/run_kaggle_qwen3b_grpo.sh summary

# %% [markdown]
# ## 7. Optional Extended Run
#
# Run this only if the main 600-step job is stable and Kaggle time remains.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh long

# %% [markdown]
# ## 8. OOM Fallback
#
# If the 3B smoke run OOMs, run this 1.5B ablation instead. It still gives a Kaggle portability result.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh fallback-1b5

# %% [markdown]
# ## 9. HF GPU Run (Multi-GPU Accelerate)
#
# Use this for the full Hugging Face / Accelerate experience with both T4 GPUs. This runs the Unsloth-optimized model using the HF distributed launcher. It still uses Unsloth for memory efficiency but correctly distributes the work across both GPUs.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh hf-smoke

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh hf-main

# %% [markdown]
# ## 10. Archive Outputs
#
# Download `/kaggle/working/qwen3b_grpo_results.tar.gz` from Kaggle outputs.

# %%
# !bash scripts/run_kaggle_qwen3b_grpo.sh archive
